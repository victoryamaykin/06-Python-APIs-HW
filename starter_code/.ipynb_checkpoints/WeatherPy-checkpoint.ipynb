# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth (23.4 Deg. perpendicular to the ecliptic).
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 60 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import csv
import json
from pprint import pprint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 654

# %%
df = pd.DataFrame({
    "City": cities
})

df.to_csv(output_data_file)

data = pd.read_csv("../output_data/cities.csv")

data["City"] = cities
data["Cloudiness"] = ""
data["Country"] = ""
data["date"] = ""
data["humidity"] = ""
data["lat"] = ""
data["lon"] = ""
data["max temp"] = ""
data["wind speed"] = ""


column_names = ["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]

data = pd.DataFrame(data, columns=column_names)
data.head()
# Out:
#            City Cloudiness Country  Date  Humidity  Lat  Lng  Max Temp  \
# 0       rikitea                      NaN       NaN  NaN  NaN       NaN
# 1      tumannyy                      NaN       NaN  NaN  NaN       NaN
# 2  beringovskiy                      NaN       NaN  NaN  NaN       NaN
# 3     cambridge                      NaN       NaN  NaN  NaN       NaN
# 4       mataura                      NaN       NaN  NaN  NaN       NaN
#
#    Wind Speed
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"

params = {
    "key": api_key,
    "units": units,
}

for index, row in data.iterrows():
    
    time.sleep(2)
    
    city = row['City']
    
    query_url = url + "appid=" + api_key + "&q=" + city
    
    print(f"Retrieving Results for Index {index}: {city}.")
    
    response = requests.get(query_url).json()
    
    try:
        data.loc[index, 'Cloudiness'] = str(response["clouds"]["all"])
        data.loc[index, 'Country'] = response["sys"]["country"]
        data.loc[index, "Date"] = response["dt"]
        data.loc[index, "Humidity"] = response["main"]["humidity"]


        data.loc[index, 'Lat'] = response["coord"]["lat"]
        data.loc[index, 'Lng'] = response["coord"]["lon"]
        data.loc[index, "Max Temp"] = response["main"]["temp_max"]
        data.loc[index, "Wind Speed"] = response["wind"]["speed"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: rikitea.
# ------------
# Retrieving Results for Index 1: tumannyy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 2: beringovskiy.
# ------------
# Retrieving Results for Index 3: cambridge.
# ------------
# Retrieving Results for Index 4: mataura.
# ------------
# Retrieving Results for Index 5: igrim.
# ------------
# Retrieving Results for Index 6: pionerskiy.
# ------------
# Retrieving Results for Index 7: nikolskoye.
# ------------
# Retrieving Results for Index 8: saskylakh.
# ------------
# Retrieving Results for Index 9: avarua.
# ------------
# Retrieving Results for Index 10: isny.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 11: port alfred.
# ------------
# Retrieving Results for Index 12: cherskiy.
# ------------
# Retrieving Results for Index 13: doctor pedro p. pena.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 14: hobart.
# ------------
# Retrieving Results for Index 15: vaini.
# ------------
# Retrieving Results for Index 16: mitu.
# ------------
# Retrieving Results for Index 17: tonekabon.
# ------------
# Retrieving Results for Index 18: beira.
# ------------
# Retrieving Results for Index 19: port hardy.
# ------------
# Retrieving Results for Index 20: yellowknife.
# ------------
# Retrieving Results for Index 21: asau.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 22: ushuaia.
# ------------
# Retrieving Results for Index 23: ulaangom.
# ------------
# Retrieving Results for Index 24: araioses.
# ------------
# Retrieving Results for Index 25: sur.
# ------------
# Retrieving Results for Index 26: kapaa.
# ------------
# Retrieving Results for Index 27: flinders.
# ------------
# Retrieving Results for Index 28: zelenoborsk.
# ------------
# Retrieving Results for Index 29: mpika.
# ------------
# Retrieving Results for Index 30: dikson.
# ------------
# Retrieving Results for Index 31: jamestown.
# ------------
# Retrieving Results for Index 32: valdepenas.
# ------------
# Retrieving Results for Index 33: nanma.
# ------------
# Retrieving Results for Index 34: at-bashi.
# ------------
# Retrieving Results for Index 35: carnarvon.
# ------------
# Retrieving Results for Index 36: lompoc.
# ------------
# Retrieving Results for Index 37: butaritari.
# ------------
# Retrieving Results for Index 38: codrington.
# ------------
# Retrieving Results for Index 39: geraldton.
# ------------
# Retrieving Results for Index 40: cape town.
# ------------
# Retrieving Results for Index 41: new norfolk.
# ------------
# Retrieving Results for Index 42: kalmunai.
# ------------
# Retrieving Results for Index 43: srednekolymsk.
# ------------
# Retrieving Results for Index 44: sitka.
# ------------
# Retrieving Results for Index 45: taolanaro.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 46: qaanaaq.
# ------------
# Retrieving Results for Index 47: grand river south east.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 48: murgab.
# ------------
# Retrieving Results for Index 49: panama city.
# ------------
# Retrieving Results for Index 50: mayya.
# ------------
# Retrieving Results for Index 51: mancio lima.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 52: binga.
# ------------
# Retrieving Results for Index 53: barrow.
# ------------
# Retrieving Results for Index 54: pakxan.
# ------------
# Retrieving Results for Index 55: saint-philippe.
# ------------
# Retrieving Results for Index 56: anshun.
# ------------
# Retrieving Results for Index 57: yerbogachen.
# ------------
# Retrieving Results for Index 58: busselton.
# ------------
# Retrieving Results for Index 59: arona.
# ------------
# Retrieving Results for Index 60: bejar.
# ------------
# Retrieving Results for Index 61: leh.
# ------------
# Retrieving Results for Index 62: luderitz.
# ------------
# Retrieving Results for Index 63: esperance.
# ------------
# Retrieving Results for Index 64: teknaf.
# ------------
# Retrieving Results for Index 65: tuktoyaktuk.
# ------------
# Retrieving Results for Index 66: kodiak.
# ------------
# Retrieving Results for Index 67: iqaluit.
# ------------
# Retrieving Results for Index 68: gualaca.
# ------------
# Retrieving Results for Index 69: los llanos de aridane.
# ------------
# Retrieving Results for Index 70: palmer.
# ------------
# Retrieving Results for Index 71: hilo.
# ------------
# Retrieving Results for Index 72: panalingaan.
# ------------
# Retrieving Results for Index 73: mount gambier.
# ------------
# Retrieving Results for Index 74: maketu.
# ------------
# Retrieving Results for Index 75: karratha.
# ------------
# Retrieving Results for Index 76: georgetown.
# ------------
# Retrieving Results for Index 77: cidreira.
# ------------
# Retrieving Results for Index 78: tasiilaq.
# ------------
# Retrieving Results for Index 79: bodaybo.
# ------------
# Retrieving Results for Index 80: illoqqortoormiut.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 81: ilulissat.
# ------------
# Retrieving Results for Index 82: puerto ayora.
# ------------
# Retrieving Results for Index 83: menongue.
# ------------
# Retrieving Results for Index 84: vaitupu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 85: zhetybay.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 86: kingisepp.
# ------------
# Retrieving Results for Index 87: bathsheba.
# ------------
# Retrieving Results for Index 88: daru.
# ------------
# Retrieving Results for Index 89: santa catarina de tepehuanes.
# ------------
# Retrieving Results for Index 90: castro.
# ------------
# Retrieving Results for Index 91: airai.
# ------------
# Retrieving Results for Index 92: hithadhoo.
# ------------
# Retrieving Results for Index 93: port elizabeth.
# ------------
# Retrieving Results for Index 94: punta arenas.
# ------------
# Retrieving Results for Index 95: bredasdorp.
# ------------
# Retrieving Results for Index 96: adrar.
# ------------
# Retrieving Results for Index 97: chuy.
# ------------
# Retrieving Results for Index 98: bembereke.
# ------------
# Retrieving Results for Index 99: cabo san lucas.
# ------------
# Retrieving Results for Index 100: singapore.
# ------------
# Retrieving Results for Index 101: padang.
# ------------
# Retrieving Results for Index 102: umzimvubu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 103: atuona.
# ------------
# Retrieving Results for Index 104: harlow.
# ------------
# Retrieving Results for Index 105: upernavik.
# ------------
# Retrieving Results for Index 106: hermanus.
# ------------
# Retrieving Results for Index 107: udachnyy.
# ------------
# Retrieving Results for Index 108: east london.
# ------------
# Retrieving Results for Index 109: biryusinsk.
# ------------
# Retrieving Results for Index 110: ambilobe.
# ------------
# Retrieving Results for Index 111: amderma.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 112: ancud.
# ------------
# Retrieving Results for Index 113: kempsey.
# ------------
# Retrieving Results for Index 114: belushya guba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 115: santa maria.
# ------------
# Retrieving Results for Index 116: nome.
# ------------
# Retrieving Results for Index 117: nizhneyansk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 118: verkhnevilyuysk.
# ------------
# Retrieving Results for Index 119: mount isa.
# ------------
# Retrieving Results for Index 120: fort nelson.
# ------------
# Retrieving Results for Index 121: snasa.
# ------------
# Retrieving Results for Index 122: zarubino.
# ------------
# Retrieving Results for Index 123: tiksi.
# ------------
# Retrieving Results for Index 124: anar darreh.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 125: hambantota.
# ------------
# Retrieving Results for Index 126: hokitika.
# ------------
# Retrieving Results for Index 127: souillac.
# ------------
# Retrieving Results for Index 128: springbok.
# ------------
# Retrieving Results for Index 129: chokurdakh.
# ------------
# Retrieving Results for Index 130: klaksvik.
# ------------
# Retrieving Results for Index 131: polovinnoye.
# ------------
# Retrieving Results for Index 132: berdigestyakh.
# ------------
# Retrieving Results for Index 133: luanda.
# ------------
# Retrieving Results for Index 134: simao.
# ------------
# Retrieving Results for Index 135: torbay.
# ------------
# Retrieving Results for Index 136: norman wells.
# ------------
# Retrieving Results for Index 137: moroni.
# ------------
# Retrieving Results for Index 138: shakawe.
# ------------
# Retrieving Results for Index 139: tabou.
# ------------
# Retrieving Results for Index 140: vila velha.
# ------------
# Retrieving Results for Index 141: guaruja.
# ------------
# Retrieving Results for Index 142: henties bay.
# ------------
# Retrieving Results for Index 143: saint george.
# ------------
# Retrieving Results for Index 144: magui.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 145: zhigalovo.
# ------------
# Retrieving Results for Index 146: mogok.
# ------------
# Retrieving Results for Index 147: albany.
# ------------
# Retrieving Results for Index 148: santo antonio do ica.
# ------------
# Retrieving Results for Index 149: gat.
# ------------
# Retrieving Results for Index 150: ust-kuyga.
# ------------
# Retrieving Results for Index 151: garowe.
# ------------
# Retrieving Results for Index 152: makaha.
# ------------
# Retrieving Results for Index 153: chunskiy.
# ------------
# Retrieving Results for Index 154: nyagan.
# ------------
# Retrieving Results for Index 155: necochea.
# ------------
# Retrieving Results for Index 156: touros.
# ------------
# Retrieving Results for Index 157: bluff.
# ------------
# Retrieving Results for Index 158: naze.
# ------------
# Retrieving Results for Index 159: san patricio.
# ------------
# Retrieving Results for Index 160: kismayo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 161: yulara.
# ------------
# Retrieving Results for Index 162: saleaula.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 163: marawi.
# ------------
# Retrieving Results for Index 164: yenangyaung.
# ------------
# Retrieving Results for Index 165: mullaitivu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 166: abai.
# ------------
# Retrieving Results for Index 167: port hawkesbury.
# ------------
# Retrieving Results for Index 168: bolungarvik.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 169: barentsburg.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 170: ponta do sol.
# ------------
# Retrieving Results for Index 171: porto novo.
# ------------
# Retrieving Results for Index 172: bodo.
# ------------
# Retrieving Results for Index 173: saposoa.
# ------------
# Retrieving Results for Index 174: cruzeiro do sul.
# ------------
# Retrieving Results for Index 175: kresttsy.
# ------------
# Retrieving Results for Index 176: rio grande.
# ------------
# Retrieving Results for Index 177: taonan.
# ------------
# Retrieving Results for Index 178: alofi.
# ------------
# Retrieving Results for Index 179: szubin.
# ------------
# Retrieving Results for Index 180: cairns.
# ------------
# Retrieving Results for Index 181: sorvag.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 182: solenzo.
# ------------
# Retrieving Results for Index 183: khor.
# ------------
# Retrieving Results for Index 184: lebu.
# ------------
# Retrieving Results for Index 185: charlestown.
# ------------
# Retrieving Results for Index 186: leningradskiy.
# ------------
# Retrieving Results for Index 187: mys shmidta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 188: constantine.
# ------------
# Retrieving Results for Index 189: road town.
# ------------
# Retrieving Results for Index 190: oranjemund.
# ------------
# Retrieving Results for Index 191: port macquarie.
# ------------
# Retrieving Results for Index 192: qasigiannguit.
# ------------
# Retrieving Results for Index 193: colares.
# ------------
# Retrieving Results for Index 194: yarmouth.
# ------------
# Retrieving Results for Index 195: novo aripuana.
# ------------
# Retrieving Results for Index 196: kargasok.
# ------------
# Retrieving Results for Index 197: faanui.
# ------------
# Retrieving Results for Index 198: ribeira grande.
# ------------
# Retrieving Results for Index 199: kavieng.
# ------------
# Retrieving Results for Index 200: faya.
# ------------
# Retrieving Results for Index 201: shimoda.
# ------------
# Retrieving Results for Index 202: markova.
# ------------
# Retrieving Results for Index 203: terrace bay.
# ------------
# Retrieving Results for Index 204: ayr.
# ------------
# Retrieving Results for Index 205: lashio.
# ------------
# Retrieving Results for Index 206: bambous virieux.
# ------------
# Retrieving Results for Index 207: flin flon.
# ------------
# Retrieving Results for Index 208: nanortalik.
# ------------
# Retrieving Results for Index 209: arteche.
# ------------
# Retrieving Results for Index 210: havre-saint-pierre.
# ------------
# Retrieving Results for Index 211: sivaki.
# ------------
# Retrieving Results for Index 212: verkhnyaya inta.
# ------------
# Retrieving Results for Index 213: kungurtug.
# ------------
# Retrieving Results for Index 214: karpogory.
# ------------
# Retrieving Results for Index 215: chara.
# ------------
# Retrieving Results for Index 216: baganga.
# ------------
# Retrieving Results for Index 217: la ronge.
# ------------
# Retrieving Results for Index 218: samalaeulu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 219: boende.
# ------------
# Retrieving Results for Index 220: ekhabi.
# ------------
# Retrieving Results for Index 221: thompson.
# ------------
# Retrieving Results for Index 222: walvis bay.
# ------------
# Retrieving Results for Index 223: natchitoches.
# ------------
# Retrieving Results for Index 224: kahului.
# ------------
# Retrieving Results for Index 225: capoterra.
# ------------
# Retrieving Results for Index 226: vanimo.
# ------------
# Retrieving Results for Index 227: dunedin.
# ------------
# Retrieving Results for Index 228: raga.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 229: stonewall.
# ------------
# Retrieving Results for Index 230: milkovo.
# ------------
# Retrieving Results for Index 231: portland.
# ------------
# Retrieving Results for Index 232: rosarito.
# ------------
# Retrieving Results for Index 233: pevek.
# ------------
# Retrieving Results for Index 234: fayaoue.
# ------------
# Retrieving Results for Index 235: shubarkuduk.
# ------------
# Retrieving Results for Index 236: mahebourg.
# ------------
# Retrieving Results for Index 237: rabo de peixe.
# ------------
# Retrieving Results for Index 238: pingshan.
# ------------
# Retrieving Results for Index 239: goundam.
# ------------
# Retrieving Results for Index 240: yaritagua.
# ------------
# Retrieving Results for Index 241: belle fourche.
# ------------
# Retrieving Results for Index 242: abu dhabi.
# ------------
# Retrieving Results for Index 243: beloha.
# ------------
# Retrieving Results for Index 244: saint-francois.
# ------------
# Retrieving Results for Index 245: ossora.
# ------------
# Retrieving Results for Index 246: pochutla.
# ------------
# Retrieving Results for Index 247: ponta delgada.
# ------------
# Retrieving Results for Index 248: del rio.
# ------------
# Retrieving Results for Index 249: ahipara.
# ------------
# Retrieving Results for Index 250: innisfail.
# ------------
# Retrieving Results for Index 251: aleksandrovsk-sakhalinskiy.
# ------------
# Retrieving Results for Index 252: ketchikan.
# ------------
# Retrieving Results for Index 253: puerto escondido.
# ------------
# Retrieving Results for Index 254: subaytilah.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 255: egvekinot.
# ------------
# Retrieving Results for Index 256: lormi.
# ------------
# Retrieving Results for Index 257: nova olimpia.
# ------------
# Retrieving Results for Index 258: kachiry.
# ------------
# Retrieving Results for Index 259: severo-yeniseyskiy.
# ------------
# Retrieving Results for Index 260: port blair.
# ------------
# Retrieving Results for Index 261: san cristobal.
# ------------
# Retrieving Results for Index 262: kalakamati.
# ------------
# Retrieving Results for Index 263: kyabe.
# ------------
# Retrieving Results for Index 264: bethel.
# ------------
# Retrieving Results for Index 265: bo phloi.
# ------------
# Retrieving Results for Index 266: hillsborough.
# ------------
# Retrieving Results for Index 267: caravelas.
# ------------
# Retrieving Results for Index 268: guerrero negro.
# ------------
# Retrieving Results for Index 269: saint anthony.
# ------------
# Retrieving Results for Index 270: barcelos.
# ------------
# Retrieving Results for Index 271: hualmay.
# ------------
# Retrieving Results for Index 272: revda.
# ------------
# Retrieving Results for Index 273: lorengau.
# ------------
# Retrieving Results for Index 274: huarmey.
# ------------
# Retrieving Results for Index 275: okato.
# ------------
# Retrieving Results for Index 276: nguiu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 277: arraial do cabo.
# ------------
# Retrieving Results for Index 278: puerto plata.
# ------------
# Retrieving Results for Index 279: straumen.
# ------------
# Retrieving Results for Index 280: acapulco.
# ------------
# Retrieving Results for Index 281: marsh harbour.
# ------------
# Retrieving Results for Index 282: jian.
# ------------
# Retrieving Results for Index 283: victoria.
# ------------
# Retrieving Results for Index 284: shingu.
# ------------
# Retrieving Results for Index 285: coulihaut.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 286: kandrian.
# ------------
# Retrieving Results for Index 287: kaputa.
# ------------
# Retrieving Results for Index 288: sinnamary.
# ------------
# Retrieving Results for Index 289: riyadh.
# ------------
# Retrieving Results for Index 290: longyearbyen.
# ------------
# Retrieving Results for Index 291: truckee.
# ------------
# Retrieving Results for Index 292: barawe.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 293: salinopolis.
# ------------
# Retrieving Results for Index 294: marcona.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 295: kenai.
# ------------
# Retrieving Results for Index 296: iskateley.
# ------------
# Retrieving Results for Index 297: auki.
# ------------
# Retrieving Results for Index 298: sao filipe.
# ------------
# Retrieving Results for Index 299: macherla.
# ------------
# Retrieving Results for Index 300: hobyo.
# ------------
# Retrieving Results for Index 301: cape coast.
# ------------
# Retrieving Results for Index 302: vao.
# ------------
# Retrieving Results for Index 303: sosva.
# ------------
# Retrieving Results for Index 304: meulaboh.
# ------------
# Retrieving Results for Index 305: goderich.
# ------------
# Retrieving Results for Index 306: mus.
# ------------
# Retrieving Results for Index 307: mitsamiouli.
# ------------
# Retrieving Results for Index 308: mar del plata.
# ------------
# Retrieving Results for Index 309: haines junction.
# ------------
# Retrieving Results for Index 310: general roca.
# ------------
# Retrieving Results for Index 311: tsihombe.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 312: celestun.
# ------------
# Retrieving Results for Index 313: iquique.
# ------------
# Retrieving Results for Index 314: greer.
# ------------
# Retrieving Results for Index 315: arosa.
# ------------
# Retrieving Results for Index 316: antsohihy.
# ------------
# Retrieving Results for Index 317: milingimbi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 318: jaen.
# ------------
# Retrieving Results for Index 319: plettenberg bay.
# ------------
# Retrieving Results for Index 320: valleyview.
# ------------
# Retrieving Results for Index 321: hamilton.
# ------------
# Retrieving Results for Index 322: kamenskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 323: poum.
# ------------
# Retrieving Results for Index 324: ambagarh chauki.
# ------------
# Retrieving Results for Index 325: cockburn town.
# ------------
# Retrieving Results for Index 326: zyryanka.
# ------------
# Retrieving Results for Index 327: kutoarjo.
# ------------
# Retrieving Results for Index 328: ucluelet.
# ------------
# Retrieving Results for Index 329: misratah.
# ------------
# Retrieving Results for Index 330: chapais.
# ------------
# Retrieving Results for Index 331: college.
# ------------
# Retrieving Results for Index 332: margate.
# ------------
# Retrieving Results for Index 333: simplicio mendes.
# ------------
# Retrieving Results for Index 334: lagoa.
# ------------
# Retrieving Results for Index 335: penzance.
# ------------
# Retrieving Results for Index 336: sentyabrskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 337: husavik.
# ------------
# Retrieving Results for Index 338: grand centre.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 339: karasjok.
# ------------
# Retrieving Results for Index 340: kamaishi.
# ------------
# Retrieving Results for Index 341: raymond.
# ------------
# Retrieving Results for Index 342: ardesen.
# ------------
# Retrieving Results for Index 343: kruisfontein.
# ------------
# Retrieving Results for Index 344: mount pleasant.
# ------------
# Retrieving Results for Index 345: kadykchan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 346: itoman.
# ------------
# Retrieving Results for Index 347: pancas.
# ------------
# Retrieving Results for Index 348: bolshaya chernigovka.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 349: dingle.
# ------------
# Retrieving Results for Index 350: kuala pilah.
# ------------
# Retrieving Results for Index 351: kudahuvadhoo.
# ------------
# Retrieving Results for Index 352: eureka.
# ------------
# Retrieving Results for Index 353: solnechnyy.
# ------------
# Retrieving Results for Index 354: sinazongwe.
# ------------
# Retrieving Results for Index 355: lavrentiya.
# ------------
# Retrieving Results for Index 356: pandan.
# ------------
# Retrieving Results for Index 357: coquimbo.
# ------------
# Retrieving Results for Index 358: mehamn.
# ------------
# Retrieving Results for Index 359: itanhaem.
# ------------
# Retrieving Results for Index 360: tabriz.
# ------------
# Retrieving Results for Index 361: arkhara.
# ------------
# Retrieving Results for Index 362: lac du bonnet.
# ------------
# Retrieving Results for Index 363: north bend.
# ------------
# Retrieving Results for Index 364: bella vista.
# ------------
# Retrieving Results for Index 365: labutta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 366: katsuura.
# ------------
# Retrieving Results for Index 367: erenhot.
# ------------
# Retrieving Results for Index 368: khatanga.
# ------------
# Retrieving Results for Index 369: ostrovnoy.
# ------------
# Retrieving Results for Index 370: kavaratti.
# ------------
# Retrieving Results for Index 371: wakkanai.
# ------------
# Retrieving Results for Index 372: prachuap khiri khan.
# ------------
# Retrieving Results for Index 373: christchurch.
# ------------
# Retrieving Results for Index 374: saint-leu.
# ------------
# Retrieving Results for Index 375: susanville.
# ------------
# Retrieving Results for Index 376: washougal.
# ------------
# Retrieving Results for Index 377: arlit.
# ------------
# Retrieving Results for Index 378: bengkulu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 379: nocupetaro.
# ------------
# Retrieving Results for Index 380: banyo.
# ------------
# Retrieving Results for Index 381: talnakh.
# ------------
# Retrieving Results for Index 382: sibolga.
# ------------
# Retrieving Results for Index 383: andra.
# ------------
# Retrieving Results for Index 384: fairbanks.
# ------------
# Retrieving Results for Index 385: cruzeiro.
# ------------
# Retrieving Results for Index 386: tigil.
# ------------
# Retrieving Results for Index 387: provideniya.
# ------------
# Retrieving Results for Index 388: yelizovo.
# ------------
# Retrieving Results for Index 389: qandahar.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 390: ola.
# ------------
# Retrieving Results for Index 391: camabatela.
# ------------
# Retrieving Results for Index 392: saryshagan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 393: coxim.
# ------------
# Retrieving Results for Index 394: kailua.
# ------------
# Retrieving Results for Index 395: ongandjera.
# ------------
# Retrieving Results for Index 396: kuche.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 397: bani.
# ------------
# Retrieving Results for Index 398: kitob.
# ------------
# Retrieving Results for Index 399: soe.
# ------------
# Retrieving Results for Index 400: pointe michel.
# ------------
# Retrieving Results for Index 401: waingapu.
# ------------
# Retrieving Results for Index 402: capreol.
# ------------
# Retrieving Results for Index 403: envira.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 404: kilindoni.
# ------------
# Retrieving Results for Index 405: atoyac.
# ------------
# Retrieving Results for Index 406: namatanai.
# ------------
# Retrieving Results for Index 407: nisia floresta.
# ------------
# Retrieving Results for Index 408: mudbidri.
# ------------
# Retrieving Results for Index 409: xiongzhou.
# ------------
# Retrieving Results for Index 410: hammerfest.
# ------------
# Retrieving Results for Index 411: tezu.
# ------------
# Retrieving Results for Index 412: nizhniy kuranakh.
# ------------
# Retrieving Results for Index 413: senador guiomard.
# ------------
# Retrieving Results for Index 414: ayan.
# ------------
# Retrieving Results for Index 415: cayenne.
# ------------
# Retrieving Results for Index 416: shaoyang.
# ------------
# Retrieving Results for Index 417: manokwari.
# ------------
# Retrieving Results for Index 418: wanaka.
# ------------
# Retrieving Results for Index 419: juneau.
# ------------
# Retrieving Results for Index 420: sao joao da barra.
# ------------
# Retrieving Results for Index 421: mana.
# ------------
# Retrieving Results for Index 422: avera.
# ------------
# Retrieving Results for Index 423: dianalund.
# ------------
# Retrieving Results for Index 424: nuuk.
# ------------
# Retrieving Results for Index 425: jumla.
# ------------
# Retrieving Results for Index 426: tuatapere.
# ------------
# Retrieving Results for Index 427: los algarrobos.
# ------------
# Retrieving Results for Index 428: tual.
# ------------
# Retrieving Results for Index 429: thinadhoo.
# ------------
# Retrieving Results for Index 430: tawkar.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 431: davila.
# ------------
# Retrieving Results for Index 432: dunmore east.
# ------------
# Retrieving Results for Index 433: basco.
# ------------
# Retrieving Results for Index 434: westport.
# ------------
# Retrieving Results for Index 435: buala.
# ------------
# Retrieving Results for Index 436: caconda.
# ------------
# Retrieving Results for Index 437: nanakuli.
# ------------
# Retrieving Results for Index 438: ginda.
# ------------
# Retrieving Results for Index 439: magistralnyy.
# ------------
# Retrieving Results for Index 440: kashi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 441: cherdyn.
# ------------
# Retrieving Results for Index 442: shiraoi.
# ------------
# Retrieving Results for Index 443: mbanza-ngungu.
# ------------
# Retrieving Results for Index 444: morondava.
# ------------
# Retrieving Results for Index 445: baghmara.
# ------------
# Retrieving Results for Index 446: bobon.
# ------------
# Retrieving Results for Index 447: tsaratanana.
# ------------
# Retrieving Results for Index 448: attawapiskat.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 449: dong xoai.
# ------------
# Retrieving Results for Index 450: narsaq.
# ------------
# Retrieving Results for Index 451: aksu.
# ------------
# Retrieving Results for Index 452: matay.
# ------------
# Retrieving Results for Index 453: taoudenni.
# ------------
# Retrieving Results for Index 454: chabahar.
# ------------
# Retrieving Results for Index 455: nantucket.
# ------------
# Retrieving Results for Index 456: casper.
# ------------
# Retrieving Results for Index 457: manica.
# ------------
# Retrieving Results for Index 458: san policarpo.
# ------------
# Retrieving Results for Index 459: camopi.
# ------------
# Retrieving Results for Index 460: cotonou.
# ------------
# Retrieving Results for Index 461: artigas.
# ------------
# Retrieving Results for Index 462: mendi.
# ------------
# Retrieving Results for Index 463: fortuna.
# ------------
# Retrieving Results for Index 464: muswellbrook.
# ------------
# Retrieving Results for Index 465: maloshuyka.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 466: falun.
# ------------
# Retrieving Results for Index 467: havelock.
# ------------
# Retrieving Results for Index 468: bakel.
# ------------
# Retrieving Results for Index 469: bhimunipatnam.
# ------------
# Retrieving Results for Index 470: gorontalo.
# ------------
# Retrieving Results for Index 471: vasyshcheve.
# ------------
# Retrieving Results for Index 472: hilton head island.
# ------------
# Retrieving Results for Index 473: dimasalang.
# ------------
# Retrieving Results for Index 474: constitucion.
# ------------
# Retrieving Results for Index 475: karlstad.
# ------------
# Retrieving Results for Index 476: hasaki.
# ------------
# Retrieving Results for Index 477: yumen.
# ------------
# Retrieving Results for Index 478: sao mateus.
# ------------
# Retrieving Results for Index 479: pokanayevka.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 480: ouango.
# ------------
# Retrieving Results for Index 481: saldanha.
# ------------
# Retrieving Results for Index 482: santa marta.
# ------------
# Retrieving Results for Index 483: sawtell.
# ------------
# Retrieving Results for Index 484: lensk.
# ------------
# Retrieving Results for Index 485: moree.
# ------------
# Retrieving Results for Index 486: tibati.
# ------------
# Retrieving Results for Index 487: canguaretama.
# ------------
# Retrieving Results for Index 488: romanovskaya.
# ------------
# Retrieving Results for Index 489: coihaique.
# ------------
# Retrieving Results for Index 490: kenora.
# ------------
# Retrieving Results for Index 491: domoni.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 492: ambodifototra.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 493: bitung.
# ------------
# Retrieving Results for Index 494: gewane.
# ------------
# Retrieving Results for Index 495: mabai.
# ------------
# Retrieving Results for Index 496: dalianwan.
# ------------
# Retrieving Results for Index 497: umm kaddadah.
# ------------
# Retrieving Results for Index 498: ridgecrest.
# ------------
# Retrieving Results for Index 499: clyde river.
# ------------
# Retrieving Results for Index 500: aklavik.
# ------------
# Retrieving Results for Index 501: tugulym.
# ------------
# Retrieving Results for Index 502: melita.
# ------------
# Retrieving Results for Index 503: upornaya.
# ------------
# Retrieving Results for Index 504: gondanglegi.
# ------------
# Retrieving Results for Index 505: prachin buri.
# ------------
# Retrieving Results for Index 506: labuan.
# ------------
# Retrieving Results for Index 507: sola.
# ------------
# Retrieving Results for Index 508: bur gabo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 509: ust-maya.
# ------------
# Retrieving Results for Index 510: zhezkazgan.
# ------------
# Retrieving Results for Index 511: tarazona.
# ------------
# Retrieving Results for Index 512: cuenca.
# ------------
# Retrieving Results for Index 513: biak.
# ------------
# Retrieving Results for Index 514: pahrump.
# ------------
# Retrieving Results for Index 515: kaitangata.
# ------------
# Retrieving Results for Index 516: rogun.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 517: chiredzi.
# ------------
# Retrieving Results for Index 518: broome.
# ------------
# Retrieving Results for Index 519: buxton.
# ------------
# Retrieving Results for Index 520: kendal.
# ------------
# Retrieving Results for Index 521: yar-sale.
# ------------
# Retrieving Results for Index 522: arman.
# ------------
# Retrieving Results for Index 523: paamiut.
# ------------
# Retrieving Results for Index 524: aswan.
# ------------
# Retrieving Results for Index 525: zaysan.
# ------------
# Retrieving Results for Index 526: chicama.
# ------------
# Retrieving Results for Index 527: santona.
# ------------
# Retrieving Results for Index 528: santana do livramento.
# ------------
# Retrieving Results for Index 529: pangody.
# ------------
# Retrieving Results for Index 530: fergus falls.
# ------------
# Retrieving Results for Index 531: groa.
# ------------
# Retrieving Results for Index 532: san joaquin.
# ------------
# Retrieving Results for Index 533: oneonta.
# ------------
# Retrieving Results for Index 534: kaeo.
# ------------
# Retrieving Results for Index 535: barddhaman.
# ------------
# Retrieving Results for Index 536: saint-michel-des-saints.
# ------------
# Retrieving Results for Index 537: shadegan.
# ------------
# Retrieving Results for Index 538: kem.
# ------------
# Retrieving Results for Index 539: hearst.
# ------------
# Retrieving Results for Index 540: cururupu.
# ------------
# Retrieving Results for Index 541: cabinda.
# ------------
# Retrieving Results for Index 542: comodoro rivadavia.
# ------------
# Retrieving Results for Index 543: half moon bay.
# ------------
# Retrieving Results for Index 544: bandarbeyla.
# ------------
# Retrieving Results for Index 545: valparaiso.
# ------------
# Retrieving Results for Index 546: tagusao.
# ------------
# Retrieving Results for Index 547: concordia.
# ------------
# Retrieving Results for Index 548: klyuchi.
# ------------
# Retrieving Results for Index 549: batemans bay.
# ------------
# Retrieving Results for Index 550: takoradi.
# ------------
# Retrieving Results for Index 551: mabaruma.
# ------------
# Retrieving Results for Index 552: tupik.
# ------------
# Retrieving Results for Index 553: gushikawa.
# ------------
# Retrieving Results for Index 554: el tigre.
# ------------
# Retrieving Results for Index 555: nouadhibou.
# ------------
# Retrieving Results for Index 556: sabha.
# ------------
# Retrieving Results for Index 557: biloela.
# ------------
# Retrieving Results for Index 558: ye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 559: dudinka.
# ------------
# Retrieving Results for Index 560: ballina.
# ------------
# Retrieving Results for Index 561: berlevag.
# ------------
# Retrieving Results for Index 562: rawannawi.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 563: akhtubinsk.
# ------------
# Retrieving Results for Index 564: malanje.
# ------------
# Retrieving Results for Index 565: guiglo.
# ------------
# Retrieving Results for Index 566: salmas.
# ------------
# Retrieving Results for Index 567: khandyga.
# ------------
# Retrieving Results for Index 568: russell.
# ------------
# Retrieving Results for Index 569: dehloran.
# ------------
# Retrieving Results for Index 570: hofn.
# ------------
# Retrieving Results for Index 571: briceno.
# ------------
# Retrieving Results for Index 572: rawson.
# ------------
# Retrieving Results for Index 573: belaya gora.
# ------------
# Retrieving Results for Index 574: decatur.
# ------------
# Retrieving Results for Index 575: thaton.
# ------------
# Retrieving Results for Index 576: petropavlovsk-kamchatskiy.
# ------------
# Retrieving Results for Index 577: pangnirtung.
# ------------
# Retrieving Results for Index 578: olga.
# ------------
# Retrieving Results for Index 579: uni.
# ------------
# Retrieving Results for Index 580: palmas.
# ------------
# Retrieving Results for Index 581: lubao.
# ------------
# Retrieving Results for Index 582: ostrogozhsk.
# ------------
# Retrieving Results for Index 583: calamar.
# ------------
# Retrieving Results for Index 584: panshi.
# ------------
# Retrieving Results for Index 585: saint-joseph.
# ------------
# Retrieving Results for Index 586: buraydah.
# ------------
# Retrieving Results for Index 587: bordighera.
# ------------
# Retrieving Results for Index 588: marzuq.
# ------------
# Retrieving Results for Index 589: okha.
# ------------
# Retrieving Results for Index 590: tonota.
# ------------
# Retrieving Results for Index 591: nizwa.
# ------------
# Retrieving Results for Index 592: teguise.
# ------------
# Retrieving Results for Index 593: palabuhanratu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 594: shelburne.
# ------------
# Retrieving Results for Index 595: isangel.
# ------------
# Retrieving Results for Index 596: jiuquan.
# ------------
# Retrieving Results for Index 597: bull savanna.
# ------------
# Retrieving Results for Index 598: severo-kurilsk.
# ------------
# Retrieving Results for Index 599: krasnoselkup.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 600: aleksandrovskiy zavod.
# ------------
# Retrieving Results for Index 601: hervey bay.
# ------------
# Retrieving Results for Index 602: ishim.
# ------------
# Retrieving Results for Index 603: ankang.
# ------------
# Retrieving Results for Index 604: consett.
# ------------
# Retrieving Results for Index 605: makakilo city.
# ------------
# Retrieving Results for Index 606: vardo.
# ------------
# Retrieving Results for Index 607: tokur.
# ------------
# Retrieving Results for Index 608: andrews.
# ------------
# Retrieving Results for Index 609: lieksa.
# ------------
# Retrieving Results for Index 610: aden.
# ------------
# Retrieving Results for Index 611: santa fe.
# ------------
# Retrieving Results for Index 612: jatibonico.
# ------------
# Retrieving Results for Index 613: praya.
# ------------
# Retrieving Results for Index 614: bubaque.
# ------------
# Retrieving Results for Index 615: vostok.
# ------------
# Retrieving Results for Index 616: grand gaube.
# ------------
# Retrieving Results for Index 617: bac lieu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 618: alyangula.
# ------------
# Retrieving Results for Index 619: cooma.
# ------------
# Retrieving Results for Index 620: tucuma.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 621: port hedland.
# ------------
# Retrieving Results for Index 622: singarayakonda.
# ------------
# Retrieving Results for Index 623: ugoofaaru.
# ------------
# Retrieving Results for Index 624: myaundzha.
# ------------
# Retrieving Results for Index 625: neuquen.
# ------------
# Retrieving Results for Index 626: artyom.
# ------------
# Retrieving Results for Index 627: sampit.
# ------------
# Retrieving Results for Index 628: anahuac.
# ------------
# Retrieving Results for Index 629: pimentel.
# ------------
# Retrieving Results for Index 630: rocha.
# ------------
# Retrieving Results for Index 631: lebyazhye.
# ------------
# Retrieving Results for Index 632: dawlatabad.
# ------------
# Retrieving Results for Index 633: brae.
# ------------
# Retrieving Results for Index 634: kushiro.
# ------------
# Retrieving Results for Index 635: jojoima.
# ------------
# Retrieving Results for Index 636: sosnovo-ozerskoye.
# ------------
# Retrieving Results for Index 637: buloh kasap.
# ------------
# Retrieving Results for Index 638: waipawa.
# ------------
# Retrieving Results for Index 639: yurimaguas.
# ------------
# Retrieving Results for Index 640: surt.
# ------------
# Retrieving Results for Index 641: pingdingshan.
# ------------
# Retrieving Results for Index 642: palu.
# ------------
# Retrieving Results for Index 643: bredy.
# ------------
# Retrieving Results for Index 644: outlook.
# ------------
# Retrieving Results for Index 645: liberia.
# ------------
# Retrieving Results for Index 646: rio gallegos.
# ------------
# Retrieving Results for Index 647: vershino-darasunskiy.
# ------------
# Retrieving Results for Index 648: llaillay.
# ------------
# Retrieving Results for Index 649: myrtle grove.
# ------------
# Retrieving Results for Index 650: te anau.
# ------------
# Retrieving Results for Index 651: keetmanshoop.
# ------------
# Retrieving Results for Index 652: can tho.
# ------------
# Retrieving Results for Index 653: boyolangu.
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data.to_csv(output_data_file)
data = data.dropna(axis = 0, how ='any') 
data.head()
# Out:
#            City Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0       rikitea         48      PF  1.552433e+09     100.0 -23.12 -134.97
# 2  beringovskiy          0      RU  1.552433e+09      90.0  63.05  179.32
# 3     cambridge         20      GB  1.552433e+09      75.0  52.20    0.12
# 4       mataura         92      NZ  1.552433e+09      90.0 -46.19  168.86
# 5         igrim         76      RU  1.552433e+09      97.0  63.19   64.42
#
#    Max Temp  Wind Speed
# 0   299.040        8.43
# 2   253.215        9.98
# 3   278.710        9.80
# 4   287.590        7.60
# 5   272.240        1.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Design the scatter plot
city_lat = data["Lat"]
max_temp = data["Max Temp"]

plt.scatter(city_lat, max_temp,marker="o", facecolors="blue", edgecolors="black", alpha=0.42)

#Create title and labels
plt.title(f"City Latitude vs. Max Temperature (03/12/2019)")

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

#Save an image of the chart
plt.savefig("../Images/lat_max_temp_scatter_plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Design the scatter plot
city_lat = data["Lat"]
humid_data = data["Humidity"]


plt.scatter(city_lat, humid_data,marker="o", facecolors="blue", edgecolors="black", alpha=0.42)

#Create title and labels
plt.title("City Latitude vs. Humidity (03/12/2019)")

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0, 105)
plt.grid()

#Save an image of the chart
plt.savefig("../Images/lat_humid_scatter_plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Design the scatter plot
city_lat = data["Lat"]
cloud_data = data["Cloudiness"]


plt.scatter(city_lat, cloud_data, marker="o", facecolors="blue", edgecolors="black", alpha=0.6)

#Create title and labels
plt.title("City Latitude vs. Cloudiness (03/12/2019)")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

#Save an image of the chart
plt.savefig("../Images/lat_cloud_scatter_plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Design the scatter plot
city_lat = data["Lat"]
wind_speed_data = data["Wind Speed"]


plt.scatter(city_lat, wind_speed_data,marker="o", facecolors="blue", edgecolors="black", alpha=0.42)

#Create title and labels
plt.title("City Latitude vs. Wind Speed (03/12/2019)")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

#Save an image of the chart
plt.savefig("../Images/lat_wind_speed_scatter_plot.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c3be03b6dcd> in <module>
#       1 #Design the scatter plot
# ----> 2 city_lat = data["Lat"]
#       3 wind_speed_data = data["Wind Speed"]
#       4
#       5
#
# NameError: name 'data' is not defined
